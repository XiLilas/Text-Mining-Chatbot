# %% [markdown]
# Members :
# - Xi WANG : lilaswang2227@gmail.com
# - Jiren REN : renjiren120@gmail.com

# %%
! python3 -m spacy download en_core_web_sm
! python3 -m spacy download fr_core_news_sm
! pip install nltk pandas scikit-learn
# Out:
# /Users/xi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.1 MB/s  0:00:04 eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.5)
# Requirement already satisfied: jinja2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.6)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (58.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2025.4.26)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (14.2.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.21.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.5.0)
# Requirement already satisfied: wrapt in /Users/xi/Library/Python/3.9/lib/python/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# /Users/xi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 2.4 MB/s  0:00:06 eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from fr-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.11.5)
# Requirement already satisfied: jinja2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.6)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (58.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.5.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2025.4.26)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (14.2.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.21.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (7.5.0)
# Requirement already satisfied: wrapt in /Users/xi/Library/Python/3.9/lib/python/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/xi/Library/Python/3.9/lib/python/site-packages (3.9.2)
# Requirement already satisfied: pandas in /Users/xi/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in /Users/xi/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: click in /Users/xi/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/xi/Library/Python/3.9/lib/python/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in /Users/xi/Library/Python/3.9/lib/python/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/xi/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)

# %% [markdown]
# # Exercise 1 : Lemmatization
#
# In this exercise, the objective is to create your own lemmatizer for french language. We will test different lemmatization approaches :
# * Based on a dictionary
# * Based on machine learning approach (you can use sklearn) or define your own architecture with pytorch
# * With and without pos tag given as input
#
# In all case you should compare your results and report performances of the proposed algorithm to [spacy](https://spacy.io/models/fr) lemmatizer (the different configuration).
#
# You are free to use any machine-learning algorihtm/model, taking or not the context of sentences such as [LinearRegression](https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.LinearRegression.html) or training your own [RNN with pytorch](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html).
# However you must always motivate your choices and compare results of the different configurations.
#
# You will send the report to *thomas.gerald@universite-paris-saclay.fr* in PDF format named as following and the code (notebook with  output of the two exercises in a zip format) :
#
#
# **report_[firstname]_[lastname].pdf**
#
# The report for the two exercises must not exceed three pages !
#
#
# ## Dataset
# To train or build your lemmatizer you have three files in *tabular separated values* format :
# * [training-set.tsv](https://thomas-gerald.fr/TMC/resources/data/training-set.tsv) that you can use to train/build your dictionnary/model
# * [testing-set.tsv](https://thomas-gerald.fr/TMC/resources/data/testing-set.tsv) used to evaluate the different approaches
# * [testing-gallica.tsv](https://thomas-gerald.fr/TMC/resources/data/testing-gallica.tsv) used as gold standard to evaluate performances [github (in french)](https://github.com/Gallicorpora/Lemmatisation)
#
# In our case we have two possibilities for a lemma:
# * (a) A sequence of characters, meaning that "to rule" an "a rule" are the same lemma
# * (b) A sequence of characters, meaning that "to rule" represent the verb, a tuple ("rule", "V") while "a rule" is represented by the tuple ("rule", "N")
# In the (a) case the size of the vocabulary (output) will be
# ## Spacy :
#
# Below a small example using spacy lemmatization
# ```python
# import spacy
# nlp = spacy.load("en_core_web_sm")
# text_a = "He is thirty years old"
# text_b = "We still are champions"
# print(f'Lemmatization A : {[(w.lemma_, w.pos_) for w in nlp(text_a)]}')
# print(f'Lemmatization B : {[(w.lemma_, w.pos_) for w in nlp(text_b)]}')
# ```

# %% [markdown]
# ### Reading data
#
# You can use pandas to read the data using tabular separator as following

# %%
import pandas as pd
train_file = "data/training-set.tsv"
pd.read_csv(train_file, sep='\t', names=["token", "lemma", "pos"])
# Out:
#           token    lemma    pos
# 0        Certes   certes    ADV
# 1             ,        ,  PONCT
# 2          rien     rien    PRO
# 3            ne       ne    ADV
# 4           dit     dire      V
# ...         ...      ...    ...
# 261384    effet    effet      N
# 261385  positif  positif      A
# 261386        .        .  PONCT
# 261387    tenir    tenir      V
# 261388        .        .  PONCT
#
# [261389 rows x 3 columns]

# %%
w_vocabulary = {'unknow_word'}
l_vocabulary = set()
lp_vocabulary = set()

with open(train_file, 'r')  as f:
    for line in f:
        try: 
            word, lemma, pos = line.split()
            w_vocabulary.add(word)
            l_vocabulary.add(lemma)
            lp_vocabulary.add((lemma, pos))
        except: 
            pass

print(f'The input vocabulary contains : {len(w_vocabulary)} words' )
print(f'The number of str lemma is :  {len(l_vocabulary)}')
print(f'The number of lemma (considering PoS) is :  {len(lp_vocabulary)}')
# Out:
# The input vocabulary contains : 23271 words
# The number of str lemma is :  15194
# The number of lemma (considering PoS) is :  16144

# %% [markdown]
# ### Lemmatization based on a dictionary

# %%
from collections import defaultdict, Counter

lemma_dict = defaultdict(Counter)          # case (a)
lemma_pos_dict = defaultdict(Counter)      # case (b)

# %%
with open(train_file, 'r') as f:
    for line in f:
        try:
            word, lemma, pos = line.strip().split()
            word = word.lower()
            lemma = lemma.lower()

            # case a : word -> lemma
            lemma_dict[word][lemma] += 1
            # case b : (word, pos) -> lemma
            lemma_pos_dict[(word, pos)][lemma] += 1

        #except:
        #    pass
        except ValueError:
            continue

print(lemma_dict)
print(lemma_pos_dict)
# Out:
# defaultdict(<class 'collections.Counter'>, {'certes': Counter({'certes': 39}), ',': Counter({',': 15911}), 'rien': Counter({'rien': 54}), 'ne': Counter({'ne': 719}), 'dit': Counter({'dire': 36}), "qu'": Counter({'que': 596, "qu'": 1}), 'une': Counter({'un': 2378, 'une': 9}), 'seconde': Counter({'second': 25, 'seconde': 4}), 'motion': Counter({'motion': 3}), 'de': Counter({'de': 12730, 'un': 167, 'du': 1, 'en_vue>de': 1, 'à_raison>de': 1}), 'censure': Counter({'censure': 3}), 'sur': Counter({'sur': 1298}), 'son': Counter({'son': 689}), 'projet': Counter({'projet': 94}), 'loi': Counter({'loi': 85}), 'reprenant': Counter({'reprendre': 2}), "l'": Counter({'le': 5066, 'il': 114, "l'": 15}), 'accord': Counter({'accord': 152}), 'du': Counter({'de': 2696, 'du': 186, 'du_coup': 1, 'à_cause_de': 1, 'au_sein_de': 1, 'un': 1, 'en_raison_de': 1}), '10': Counter({'10': 120}), 'avril': Counter({'avril': 64}), "n'": Counter({'ne': 766}), 'aurait': Counter({'avoir': 66}), 'pas': Counter({'pas': 846}), 'été': Counter({'être': 599, 'été': 50}), 'la': Counter({'le': 7240, 'la': 36}), 'bonne': Counter({'bon': 51, 'bonne': 2}), 'mais': Counter({'mais': 627, 'mais_aussi': 1}), 'cette': Counter({'ce': 577}), 'probabilité': Counter({'probabilité': 3}), 'reconnaissent': Counter({'reconnaître': 2}), 'les': Counter({'le': 4959, 'il': 64, 'les': 12}), 'socialistes': Counter({'socialiste': 16}), 'était': Counter({'être': 236}), 'plus': Counter({'plus': 910, 'le_plus': 2, 'plus_tard': 1}), 'plausible': Counter({'plausible': 2}), '.': Counter({'.': 8630, ',': 1}), 'toujours': Counter({'toujours': 106}), 'est': Counter({'être': 1807, 'est': 56}), '-il': Counter({'il': 58}), 'que': Counter({'que': 1290, 'alors_que': 2}), 'le': Counter({'le': 5171, 'il': 1}), 'gouvernement': Counter({'gouvernement': 176}), 'a': Counter({'avoir': 1699, 'à': 190, 'a': 5, 'être_question_de': 1, 'a_longue_échéance': 1}), 'cédé': Counter({'céder': 8}), 'alors_que': Counter({'alors_que': 95}), 'ses': Counter({'son': 499}), 'adversaires': Counter({'adversaire': 6}), 'politiques': Counter({'politique': 38, 'politiques': 17}), 'proposent': Counter({'proposer': 8}), 'aucune': Counter({'aucun': 28}), 'solution': Counter({'solution': 27}), 'alternative': Counter({'alternatif': 2, 'alternative': 1}), 'et': Counter({'et': 4197}), 'considèrent': Counter({'considérer': 6}), 'avec_un_bel_ensemble': Counter({'avec_un_bel_ensemble': 1}), 'défense': Counter({'défense': 36}), 'des': Counter({'de': 2900, 'un': 1211, 'des': 208, 'du_fait_de': 1, "sous_l'effet_de": 1, 'en_raison_de': 1}), 'intérêts': Counter({'intérêt': 37}), 'malades': Counter({'malade': 3}), 'passe': Counter({'passer': 40, 'passe': 2}), 'par': Counter({'par': 1492}), 'maintien': Counter({'maintien': 27}), "d'": Counter({'de': 3245, 'un': 86, "d'": 2, 'loin_de': 1, 'afin_de': 1}), 'un': Counter({'un': 2364}), 'système': Counter({'système': 93}), 'qui': Counter({'qui': 1678}), 'aboutit': Counter({'aboutir': 5}), 'à': Counter({'à': 3826, 'à_long_terme': 1}), 'multiplier': Counter({'multiplier': 2}), 'actes': Counter({'acte': 4}), 'inutiles': Counter({'inutile': 2}), 'au': Counter({'à': 986, 'au': 20, 'par_rapport_à': 1}), 'dépassement': Counter({'dépassement': 1}), 'généralisé': Counter({'généraliser': 4}), 'honoraires': Counter({'honoraires': 2}), '"': Counter({'"': 3440}), 'sécu': Counter({'sécu': 5}), 'du_coup': Counter({'du_coup': 13}), 'il': Counter({'il': 1002}), "s'": Counter({'il': 486, 'se': 470, 'si': 40, "s'": 6}), 'incliné': Counter({'incliner': 1}), 'devant': Counter({'devant': 46, 'devoir': 22}), 'corporatisme': Counter({'corporatisme': 3}), 'représentants': Counter({'représentant': 19}), 'corps': Counter({'corps': 5}), 'médical': Counter({'médical': 2}), '(': Counter({')': 1020, '(': 889}), 'traversent': Counter({'traverser': 5}), 'même': Counter({'même': 241}), 'crise': Counter({'crise': 144}), 'représentativité': Counter({'représentativité': 1}), 'syndicalistes': Counter({'syndicaliste': 8}), 'monde': Counter({'monde': ...
# defaultdict(<class 'collections.Counter'>, {('certes', 'ADV'): Counter({'certes': 39}), (',', 'PONCT'): Counter({',': 15911}), ('rien', 'PRO'): Counter({'rien': 51}), ('ne', 'ADV'): Counter({'ne': 719}), ('dit', 'V'): Counter({'dire': 36}), ("qu'", 'C'): Counter({'que': 342}), ('une', 'D'): Counter({'un': 2323, 'une': 3}), ('seconde', 'A'): Counter({'second': 25}), ('motion', 'N'): Counter({'motion': 3}), ('de', 'P'): Counter({'de': 12714, 'en_vue>de': 1, 'à_raison>de': 1}), ('censure', 'N'): Counter({'censure': 3}), ('sur', 'P'): Counter({'sur': 1298}), ('son', 'D'): Counter({'son': 687}), ('projet', 'N'): Counter({'projet': 94}), ('loi', 'N'): Counter({'loi': 85}), ('reprenant', 'V'): Counter({'reprendre': 2}), ("l'", 'D'): Counter({'le': 5065, "l'": 6}), ('accord', 'N'): Counter({'accord': 152}), ('du', 'P+D'): Counter({'de': 2696, 'du': 146}), ('10', 'A'): Counter({'10': 22}), ('avril', 'N'): Counter({'avril': 64}), ("n'", 'ADV'): Counter({'ne': 766}), ('aurait', 'V'): Counter({'avoir': 66}), ('pas', 'ADV'): Counter({'pas': 834}), ('été', 'V'): Counter({'être': 599}), ('la', 'D'): Counter({'le': 7206, 'la': 32}), ('bonne', 'A'): Counter({'bon': 51, 'bonne': 2}), ('mais', 'C'): Counter({'mais': 616, 'mais_aussi': 1}), ('cette', 'D'): Counter({'ce': 577}), ('probabilité', 'N'): Counter({'probabilité': 3}), ('reconnaissent', 'V'): Counter({'reconnaître': 2}), ('les', 'D'): Counter({'le': 4959, 'les': 5}), ('socialistes', 'N'): Counter({'socialiste': 12}), ('était', 'V'): Counter({'être': 236}), ('plus', 'ADV'): Counter({'plus': 901, 'le_plus': 2, 'plus_tard': 1}), ('plausible', 'A'): Counter({'plausible': 2}), ('.', 'PONCT'): Counter({'.': 8630, ',': 1}), ('toujours', 'ADV'): Counter({'toujours': 106}), ('est', 'V'): Counter({'être': 1807}), ('-il', 'CL'): Counter({'il': 58}), ('que', 'C'): Counter({'que': 920, 'alors_que': 2}), ('le', 'D'): Counter({'le': 5023}), ('gouvernement', 'N'): Counter({'gouvernement': 176}), ('a', 'V'): Counter({'avoir': 1699, 'être_question_de': 1}), ('cédé', 'V'): Counter({'céder': 8}), ('alors_que', 'C'): Counter({'alors_que': 95}), ('ses', 'D'): Counter({'son': 499}), ('adversaires', 'N'): Counter({'adversaire': 6}), ('politiques', 'A'): Counter({'politique': 30}), ('proposent', 'V'): Counter({'proposer': 8}), ('aucune', 'D'): Counter({'aucun': 24}), ('solution', 'N'): Counter({'solution': 27}), ('alternative', 'A'): Counter({'alternatif': 2}), ('et', 'C'): Counter({'et': 4197}), ('considèrent', 'V'): Counter({'considérer': 6}), ('avec_un_bel_ensemble', 'ADV'): Counter({'avec_un_bel_ensemble': 1}), ('défense', 'N'): Counter({'défense': 36}), ('des', 'P+D'): Counter({'de': 2895, 'des': 208}), ('intérêts', 'N'): Counter({'intérêt': 37}), ('malades', 'N'): Counter({'malade': 3}), ('passe', 'V'): Counter({'passer': 40}), ('par', 'P'): Counter({'par': 1491}), ('maintien', 'N'): Counter({'maintien': 27}), ("d'", 'P'): Counter({'de': 3231, 'loin_de': 1, "d'": 1, 'afin_de': 1}), ('un', 'D'): Counter({'un': 2265}), ('système', 'N'): Counter({'système': 93}), ('qui', 'PRO'): Counter({'qui': 1677}), ('aboutit', 'V'): Counter({'aboutir': 5}), ('à', 'P'): Counter({'à': 3826}), ('multiplier', 'V'): Counter({'multiplier': 2}), ('actes', 'N'): Counter({'acte': 4}), ('inutiles', 'A'): Counter({'inutile': 2}), ('au', 'P+D'): Counter({'à': 986, 'au': 20}), ('dépassement', 'N'): Counter({'dépassement': 1}), ('généralisé', 'V'): Counter({'généraliser': 4}), ('honoraires', 'N'): Counter({'honoraires': 2}), ('"', 'PONCT'): Counter({'"': 3440}), ('sécu', 'N'): Counter({'sécu': 5}), ('du_coup', 'ADV'): Counter({'du_coup': 13}), ('il', 'CL'): Counter({'il': 1002}), ("s'", 'CL'): Counter({'il': 486, 'se': 470, "s'": 6}), ('incliné', 'V'): Counter({'incliner': 1}), ('devant', 'P'): Counter({'devant': 46}), ('corporatisme', 'N'): Counter({'corporatisme': 3}), ('représentants', 'N'): Counter({'représentant': 19}), ('corps', 'N'): Counter({'corps': 5}), ('médical', 'A'): Counter({'médical': 2}), ('(', 'PONCT'): Counter({')':  ...

# %% [markdown]
# ##### Trainning Lemmatization based on dictionary

# %%
# case (a): without POS
dict_lemma = {
    word: counter.most_common(1)[0][0]
    for word, counter in lemma_dict.items()
}

# case (b): with POS
dict_lemma_pos = {
    key: counter.most_common(1)[0][0]
    for key, counter in lemma_pos_dict.items()
}

print(dict_lemma)
print(dict_lemma_pos)
# Out:
# {'certes': 'certes', ',': ',', 'rien': 'rien', 'ne': 'ne', 'dit': 'dire', "qu'": 'que', 'une': 'un', 'seconde': 'second', 'motion': 'motion', 'de': 'de', 'censure': 'censure', 'sur': 'sur', 'son': 'son', 'projet': 'projet', 'loi': 'loi', 'reprenant': 'reprendre', "l'": 'le', 'accord': 'accord', 'du': 'de', '10': '10', 'avril': 'avril', "n'": 'ne', 'aurait': 'avoir', 'pas': 'pas', 'été': 'être', 'la': 'le', 'bonne': 'bon', 'mais': 'mais', 'cette': 'ce', 'probabilité': 'probabilité', 'reconnaissent': 'reconnaître', 'les': 'le', 'socialistes': 'socialiste', 'était': 'être', 'plus': 'plus', 'plausible': 'plausible', '.': '.', 'toujours': 'toujours', 'est': 'être', '-il': 'il', 'que': 'que', 'le': 'le', 'gouvernement': 'gouvernement', 'a': 'avoir', 'cédé': 'céder', 'alors_que': 'alors_que', 'ses': 'son', 'adversaires': 'adversaire', 'politiques': 'politique', 'proposent': 'proposer', 'aucune': 'aucun', 'solution': 'solution', 'alternative': 'alternatif', 'et': 'et', 'considèrent': 'considérer', 'avec_un_bel_ensemble': 'avec_un_bel_ensemble', 'défense': 'défense', 'des': 'de', 'intérêts': 'intérêt', 'malades': 'malade', 'passe': 'passer', 'par': 'par', 'maintien': 'maintien', "d'": 'de', 'un': 'un', 'système': 'système', 'qui': 'qui', 'aboutit': 'aboutir', 'à': 'à', 'multiplier': 'multiplier', 'actes': 'acte', 'inutiles': 'inutile', 'au': 'à', 'dépassement': 'dépassement', 'généralisé': 'généraliser', 'honoraires': 'honoraires', '"': '"', 'sécu': 'sécu', 'du_coup': 'du_coup', 'il': 'il', "s'": 'il', 'incliné': 'incliner', 'devant': 'devant', 'corporatisme': 'corporatisme', 'représentants': 'représentant', 'corps': 'corps', 'médical': 'médical', '(': ')', 'traversent': 'traverser', 'même': 'même', 'crise': 'crise', 'représentativité': 'représentativité', 'syndicalistes': 'syndicaliste', 'monde': 'monde', 'salarié': 'salarié', ')': '(', 'préoccupés': 'préoccupé', 'leurs': 'son', 'rivalités': 'rivalité', 'internes': 'interne', 'attentes': 'attente', 'médecins': 'médecin', 'à_la_recherche_de': 'à_la_recherche_de', 'règles': 'règle', 'jeu': 'jeu', 'claires': 'clair', 'acceptables': 'acceptable', 'se': 'se', 'résout': 'résoudre', 'donc': 'donc', 'renvoyer': 'renvoyer', 'balle': 'balle', 'dans': 'dans', 'camp': 'camp', 'partenaires': 'partenaire', 'ont': 'avoir', 'amplement': 'amplement', 'fait': 'faire', 'preuve': 'preuve', 'leur': 'son', 'incapacité': 'incapacité', 'gérer': 'gérer', 'santé': 'santé', 'ironie': 'ironie', 'sort': 'sortir', 'chacun': 'chacun', 'attend': 'attendre', 'ce': 'ce', 'conseil': 'conseil', 'etat': 'etat', 'annule': 'annuler', 'dans_les_prochains_jours': 'dans_les_prochains_jours', 'convention': 'convention', 'médicale': 'médical', '1989': '1989', 'négociée': 'négocier', 'assurance_-_maladie': 'assurance-maladie', '...': '...', 'm.': 'm.', 'teulade': 'teulade', 'peut': 'pouvoir', 'à_juste_titre': 'à_juste_titre', 'considérer': 'considérer', 'crédibilité': 'crédibilité', 'conventionnel': 'conventionnel', 'en_jeu': 'en_jeu', 'on': 'on', 'voit': 'voir', 'mal': 'mal', 'comment': 'comment', 'pourra': 'pouvoir', 'amener': 'amener', 'interlocuteurs': 'interlocuteur', 'clarifier': 'clarifier', 'positions': 'position', 'fortifier': 'fortifier', 'signatures': 'signature', 'en_dépit_des': 'en_dépit_de', 'mesures': 'mesure', 'rétorsion': 'rétorsion', 'gel': 'gel', 'revalorisation': 'revalorisation', 'tarification': 'tarification', 'visite': 'visite', 'à_domicile': 'à_domicile', 'petits': 'petit', 'chirurgicaux': 'chirurgical', 'ou': 'ou', 'menaces': 'menace', 'à_peine': 'à_peine', 'voilées': 'voilé', 'sanctions': 'sanction', 'contre': 'contre', 'praticiens': 'praticien', 'coupables': 'coupable', 'dépassements': 'dépassement', 'sauvages': 'sauvage', 'augmentation': 'augmentation', 'cotisations': 'cotisation', 'retraite': 'retraite', 'impose': 'imposer', 'véritable': 'véritable', 'date': 'date', '-': '-', 'butoir': 'butoir', "d'_autre_part": "d'autre_part", 'neuf': 'neuf', 'mois': 'mois', 'élections': 'élection', 'législatives':  ...
# {('certes', 'ADV'): 'certes', (',', 'PONCT'): ',', ('rien', 'PRO'): 'rien', ('ne', 'ADV'): 'ne', ('dit', 'V'): 'dire', ("qu'", 'C'): 'que', ('une', 'D'): 'un', ('seconde', 'A'): 'second', ('motion', 'N'): 'motion', ('de', 'P'): 'de', ('censure', 'N'): 'censure', ('sur', 'P'): 'sur', ('son', 'D'): 'son', ('projet', 'N'): 'projet', ('loi', 'N'): 'loi', ('reprenant', 'V'): 'reprendre', ("l'", 'D'): 'le', ('accord', 'N'): 'accord', ('du', 'P+D'): 'de', ('10', 'A'): '10', ('avril', 'N'): 'avril', ("n'", 'ADV'): 'ne', ('aurait', 'V'): 'avoir', ('pas', 'ADV'): 'pas', ('été', 'V'): 'être', ('la', 'D'): 'le', ('bonne', 'A'): 'bon', ('mais', 'C'): 'mais', ('cette', 'D'): 'ce', ('probabilité', 'N'): 'probabilité', ('reconnaissent', 'V'): 'reconnaître', ('les', 'D'): 'le', ('socialistes', 'N'): 'socialiste', ('était', 'V'): 'être', ('plus', 'ADV'): 'plus', ('plausible', 'A'): 'plausible', ('.', 'PONCT'): '.', ('toujours', 'ADV'): 'toujours', ('est', 'V'): 'être', ('-il', 'CL'): 'il', ('que', 'C'): 'que', ('le', 'D'): 'le', ('gouvernement', 'N'): 'gouvernement', ('a', 'V'): 'avoir', ('cédé', 'V'): 'céder', ('alors_que', 'C'): 'alors_que', ('ses', 'D'): 'son', ('adversaires', 'N'): 'adversaire', ('politiques', 'A'): 'politique', ('proposent', 'V'): 'proposer', ('aucune', 'D'): 'aucun', ('solution', 'N'): 'solution', ('alternative', 'A'): 'alternatif', ('et', 'C'): 'et', ('considèrent', 'V'): 'considérer', ('avec_un_bel_ensemble', 'ADV'): 'avec_un_bel_ensemble', ('défense', 'N'): 'défense', ('des', 'P+D'): 'de', ('intérêts', 'N'): 'intérêt', ('malades', 'N'): 'malade', ('passe', 'V'): 'passer', ('par', 'P'): 'par', ('maintien', 'N'): 'maintien', ("d'", 'P'): 'de', ('un', 'D'): 'un', ('système', 'N'): 'système', ('qui', 'PRO'): 'qui', ('aboutit', 'V'): 'aboutir', ('à', 'P'): 'à', ('multiplier', 'V'): 'multiplier', ('actes', 'N'): 'acte', ('inutiles', 'A'): 'inutile', ('au', 'P+D'): 'à', ('dépassement', 'N'): 'dépassement', ('généralisé', 'V'): 'généraliser', ('honoraires', 'N'): 'honoraires', ('"', 'PONCT'): '"', ('sécu', 'N'): 'sécu', ('du_coup', 'ADV'): 'du_coup', ('il', 'CL'): 'il', ("s'", 'CL'): 'il', ('incliné', 'V'): 'incliner', ('devant', 'P'): 'devant', ('corporatisme', 'N'): 'corporatisme', ('représentants', 'N'): 'représentant', ('corps', 'N'): 'corps', ('médical', 'A'): 'médical', ('(', 'PONCT'): ')', ('traversent', 'V'): 'traverser', ('même', 'A'): 'même', ('crise', 'N'): 'crise', ('représentativité', 'N'): 'représentativité', ('syndicalistes', 'N'): 'syndicaliste', ('monde', 'N'): 'monde', ('salarié', 'A'): 'salarié', (')', 'PONCT'): '(', ('préoccupés', 'A'): 'préoccupé', ('leurs', 'D'): 'son', ('rivalités', 'N'): 'rivalité', ('internes', 'A'): 'interne', ('attentes', 'N'): 'attente', ('médecins', 'N'): 'médecin', ('à_la_recherche_de', 'P'): 'à_la_recherche_de', ('règles', 'N'): 'règle', ('jeu', 'N'): 'jeu', ('claires', 'A'): 'clair', ('acceptables', 'A'): 'acceptable', ('se', 'CL'): 'se', ('résout', 'V'): 'résoudre', ('donc', 'ADV'): 'donc', ('renvoyer', 'V'): 'renvoyer', ('balle', 'N'): 'balle', ('dans', 'P'): 'dans', ('camp', 'N'): 'camp', ('partenaires', 'N'): 'partenaire', ('ont', 'V'): 'avoir', ('amplement', 'ADV'): 'amplement', ('fait', 'V'): 'faire', ('preuve', 'N'): 'preuve', ('leur', 'D'): 'son', ('incapacité', 'N'): 'incapacité', ('gérer', 'V'): 'gérer', ('santé', 'N'): 'santé', ('ironie', 'N'): 'ironie', ('sort', 'N'): 'sort', ('chacun', 'PRO'): 'chacun', ('attend', 'V'): 'attendre', ('ce', 'PRO'): 'ce', ('que', 'PRO'): 'que', ('conseil', 'N'): 'conseil', ('etat', 'N'): 'etat', ('annule', 'V'): 'annuler', ('dans_les_prochains_jours', 'ADV'): 'dans_les_prochains_jours', ('convention', 'N'): 'convention', ('médicale', 'A'): 'médical', ('1989', 'N'): '1989', ('négociée', 'V'): 'négocier', ('assurance_-_maladie', 'N'): 'assurance-maladie', ('...', 'PONCT'): '...', ('m.', 'N'): 'm.', ('teulade', 'N'): 'teulade', ('peut', 'V'): 'pouvoir', ('à_juste_titre', 'ADV'): 'à_juste_titre', ('considérer', 'V'): 'considérer', ('crédib ...

# %%
# Define lemmatization test on the dictionary trainning
def lemmatize_dict(word, pos=None):
    word = word.lower()
    if pos is not None and (word, pos) in dict_lemma_pos:
        return dict_lemma_pos[(word, pos)]
    if word in dict_lemma:
        return dict_lemma[word]
    return word 

print(lemmatize_dict("dit"))
print(lemmatize_dict("dit", "V"))
# Out:
# dire
# dire

# %% [markdown]
# ##### Accuracy of lemmatization of dictionary

# %%
test_file = "data/testing-set.tsv"
pd.read_csv(test_file, sep='\t', names=["token", "lemma", "pos"])
test_data_dict = []

with open(test_file, 'r', encoding='utf-8') as f:
    for line in f:
        try:
            word, lemma, pos = line.strip().split()
            test_data_dict.append((word.lower(), lemma.lower(), pos))
        #except:
        #    pass
        except ValueError:
            continue

print(f'The test set contains {len(test_data_dict)} tokens.')
# Out:
# The test set contains 16694 tokens.

# %%
def evaluate(lemmatizer, data, use_pos=False):
    correct = 0
    total = 0

    for word, gold_lemma, pos in data:
        if use_pos:
            pred = lemmatizer(word, pos)
        else:
            pred = lemmatizer(word)

        if pred == gold_lemma:
            correct += 1
        total += 1

    return correct / total

acc_no_pos = evaluate(lemmatize_dict, test_data_dict, use_pos=False)
acc_with_pos = evaluate(lemmatize_dict, test_data_dict, use_pos=True)

print(f"Dictionary lemmatizer (no POS): {acc_no_pos:.4f}")
print(f"Dictionary lemmatizer (with POS): {acc_with_pos:.4f}")
# Out:
# Dictionary lemmatizer (no POS): 0.9475
# Dictionary lemmatizer (with POS): 0.9611

# %% [markdown]
# Using POS information improves lemmatization accuracy, especially for ambiguous forms that can correspond to different lemmas depending on their syntactic category (e.g. nouns vs verbs).
#
# However, the POS-based dictionary approach is sensitive to POS tagging consistency and suffers from out-of-vocabulary errors when unseen word–POS combinations appear in the test set.

# %% [markdown]
# ### Based on Machine Learning (sklearn)

# %%
def extract_rule(word, lemma, max_len=6):
    """
    from word -> lemma get their suffix
    then return (word_suffix, lemma_suffix)
    """
    for i in range(1, min(len(word), max_len) + 1):
        if word[:-i] == lemma[:-i]:
            return (word[-i:], lemma[-i:])
    return word, lemma



def make_features(word, pos):
    """extract suffix features from the word"""
    word = word.lower()
    return {
        "suffix1": word[-1:] if len(word) >= 1 else "",
        "suffix2": word[-2:] if len(word) >= 2 else "",
        "suffix3": word[-3:] if len(word) >= 3 else "",
        "suffix4": word[-4:] if len(word) >= 4 else "",
        "pos": pos
    }

# %%
X = []
y = []

with open(train_file, 'r', encoding='utf-8') as f:
    for line in f:
        #print("line:", line)
        line = line.rstrip('\n')
        if not line:
            continue
        try:
            word, lemma, pos = line.split()
        except ValueError:
            continue

        word = word.lower()
        lemma = lemma.lower()
        w_suf, l_suf = extract_rule(word, lemma)

        X.append(make_features(word, pos))
        y.append(f"{w_suf}→{l_suf}")

print(len(X), len(y))
print(X[:10])
print(y[:10])
# Out:
# 261378 261378
# [{'suffix1': 's', 'suffix2': 'es', 'suffix3': 'tes', 'suffix4': 'rtes', 'pos': 'ADV'}, {'suffix1': ',', 'suffix2': '', 'suffix3': '', 'suffix4': '', 'pos': 'PONCT'}, {'suffix1': 'n', 'suffix2': 'en', 'suffix3': 'ien', 'suffix4': 'rien', 'pos': 'PRO'}, {'suffix1': 'e', 'suffix2': 'ne', 'suffix3': '', 'suffix4': '', 'pos': 'ADV'}, {'suffix1': 't', 'suffix2': 'it', 'suffix3': 'dit', 'suffix4': '', 'pos': 'V'}, {'suffix1': "'", 'suffix2': "u'", 'suffix3': "qu'", 'suffix4': '', 'pos': 'C'}, {'suffix1': 'e', 'suffix2': 'ne', 'suffix3': 'une', 'suffix4': '', 'pos': 'D'}, {'suffix1': 'e', 'suffix2': 'de', 'suffix3': 'nde', 'suffix4': 'onde', 'pos': 'A'}, {'suffix1': 'n', 'suffix2': 'on', 'suffix3': 'ion', 'suffix4': 'tion', 'pos': 'N'}, {'suffix1': 'e', 'suffix2': 'de', 'suffix3': '', 'suffix4': '', 'pos': 'P'}]
# ['s→s', ',→,', 'n→n', 'e→e', 'dit→dire', "'→e", 'une→un', 'seconde→second', 'n→n', 'e→e']

# %% [markdown]
# ##### Trainning Lemmatization based on ML sk-learn

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

ml_model = Pipeline([
    ("vectorizer", DictVectorizer()),
    ("classifier", LogisticRegression(max_iter=200))
])

#this one is too long to run, so we limit to first 10,000 samples.
#ml_model.fit(X, y) 
ml_model.fit(X[:10000], y[:10000])
# Out:
# Pipeline(steps=[('vectorizer', DictVectorizer()),
#                 ('classifier', LogisticRegression(max_iter=200))])

# %%
#test the model
print(ml_model.predict([make_features('ties', 'N')]))
print(ml_model.predict([make_features('onet', 'V')]))
# Out:
# ['économies→économie']
# ['t→t']

# %%
def apply_rule(word, rule_str):
    """
    Apply a predicted transformation rule to a word.
    """
    w_suf, l_suf = rule_str.split("→")

    if word.endswith(w_suf):
        return word[:-len(w_suf)] + l_suf
    else:
        return word


def lemmatize_ml(word, pos=None):
    """Lemmatize a word using the ML model."""
    word = word.lower()

    features = make_features(word, pos)

    rule_str = ml_model.predict([features])[0]
    return apply_rule(word, rule_str)

# test the ML lemmatizer
print(lemmatize_ml("une", "D"))       # un
print(lemmatize_ml("dit", "V"))       # dire
print(lemmatize_ml("seconde", "A"))   # seconde
# Out:
# un
# dir
# seconde

# %% [markdown]
# ##### Accuracy of lemmatization of sk-learn

# %%
test_file = "data/testing-set.tsv"

test_data_skl = []

with open(test_file, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        parts = line.split('\t')
        if len(parts) != 3:
            continue

        word, lemma, pos = parts
        test_data_skl.append((word.lower(), lemma.lower(), pos))


def evaluate_case_a(lemmatizer, data):
    correct = 0
    total = 0

    for word, gold_lemma, pos in data:
        pred = lemmatizer(word, pos)
        if pred == gold_lemma:
            correct += 1
        total += 1

    return correct / total


def evaluate_case_b(lemmatizer, data):
    correct = 0
    total = 0

    for word, gold_lemma, pos in data:
        pred = lemmatizer(word, pos)
        if (pred, pos) == (gold_lemma, pos):
            correct += 1
        total += 1

    return correct / total


acc_a = evaluate_case_a(lemmatize_ml, test_data_skl)
acc_b = evaluate_case_b(lemmatize_ml, test_data_skl)

print(f"ML lemmatizer – (no pos) lemma: {acc_a:.4f}")
print(f"ML lemmatizer – (with pos) lemma: {acc_b:.4f}")
# Out:
# ML lemmatizer – (no pos) lemma: 0.8425
# ML lemmatizer – (with pos) lemma: 0.8425

# %% [markdown]
# We used a LinearRegression model from sklearn as a baseline machine-learning approach for lemmatization.
#
# Words were represented using suffix-based features (last 1–4 characters) and part-of-speech tags.
#
# sklearn model got a lower accuracy than dictionary model, probably due to a lower quantities of training set.
#
# Although RNN-based models implemented in PyTorch could potentially capture more complex morphological patterns, they require larger datasets and sentence-level context. Therefore, we did not consider them in this exercise.

# %% [markdown]
# ### Based on SpaCy (fr_core_news_sm)

# %%
import spacy
#nlp = spacy.load("en_core_web_sm")
#text_a = "He is thirty years old"
#text_b = "We still are champions"
nlp = spacy.load("fr_core_news_sm")
text_a = "Il a trente ans."
text_b = "Nous sommes toujours champions."
print(f'Lemmatization text A : {[(w.lemma_, w.pos_) for w in nlp(text_a)]}')
print(f'Lemmatization text B : {[(w.lemma_, w.pos_) for w in nlp(text_b)]}')
# Out:
# /Users/xi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Lemmatization text A : [('il', 'PRON'), ('avoir', 'AUX'), ('trente', 'NUM'), ('an', 'NOUN'), ('.', 'PUNCT')]
# Lemmatization text B : [('nous', 'PRON'), ('être', 'AUX'), ('toujours', 'ADV'), ('champion', 'ADJ'), ('.', 'PUNCT')]

# %%
def compare_with_spacy(text, my_lemmatizer, pass_pos_to_my_model=False):
    """
    my_lemmatizer: lemmatize_dict or lemmatize_ml
    pass_pos_to_my_model:
      - False: call my_lemmatizer(word, None)
      - True : call my_lemmatizer(word, spacy_pos)
    """
    doc = nlp(text)
    rows = []
    for tok in doc:
        word = tok.text
        spacy_pos = tok.pos_
        spacy_lemma = tok.lemma_

        if pass_pos_to_my_model:
            my_lemma = my_lemmatizer(word, spacy_pos)
        else:
            my_lemma = my_lemmatizer(word, None)

        rows.append({
            "word": word,
            "spacy_pos": spacy_pos,
            "spacy_lemma": spacy_lemma,
            "my_lemma": my_lemma
        })
    return pd.DataFrame(rows)

# %%
# Compare with dictionary lemmatizer
print("=== Dictionary vs spaCy ===")
display(compare_with_spacy(text_a, lemmatize_dict, pass_pos_to_my_model=False))
display(compare_with_spacy(text_b, lemmatize_dict, pass_pos_to_my_model=False))

# Compare with ML (sklearn) lemmatizer
print("=== ML sklearn vs spaCy ===")
display(compare_with_spacy(text_a, lemmatize_ml, pass_pos_to_my_model=False))
display(compare_with_spacy(text_b, lemmatize_ml, pass_pos_to_my_model=False))
# Out:
# === Dictionary vs spaCy ===
#      word spacy_pos spacy_lemma my_lemma
# 0      Il      PRON          il       il
# 1       a       AUX       avoir    avoir
# 2  trente       NUM      trente   trente
# 3     ans      NOUN          an       an
# 4       .     PUNCT           .        .
#         word spacy_pos spacy_lemma   my_lemma
# 0       Nous      PRON        nous         il
# 1     sommes       AUX        être       être
# 2   toujours       ADV    toujours   toujours
# 3  champions       ADJ    champion  champions
# 4          .     PUNCT           .          .
# === ML sklearn vs spaCy ===
#      word spacy_pos spacy_lemma my_lemma
# 0      Il      PRON          il       il
# 1       a       AUX       avoir    avoir
# 2  trente       NUM      trente   trente
# 3     ans      NOUN          an      ans
# 4       .     PUNCT           .        .
#         word spacy_pos spacy_lemma   my_lemma
# 0       Nous      PRON        nous       nous
# 1     sommes       AUX        être     sommes
# 2   toujours       ADV    toujours   toujours
# 3  champions       ADJ    champion  champions
# 4          .     PUNCT           .          .

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The dictionary-based lemmatizer was trained on the full training set and can be evaluated on the full test set (261378 tokens) efficiently. In contrast, due to computational constraints, the sklearn LinearRegression model was trained (and evaluated) on a 10000-token subset.
#
# Therefore, the dictionary-based approach achieves higher accuracy than the sklearn model both without POS (0.9475 > 0.8425) and with POS (0.9611 > 0.8425). POS information improves the dictionary baseline by reducing ambiguity in (word, POS) mappings, while it does not improve the sklearn model in our setting.
#
# The qualitative comparison with spaCy is consistent with these results: the dictionary method matches spaCy on frequent in-vocabulary forms, whereas the sklearn model diverges more often on plural nouns and irregular verb forms. Overall, spaCy remains stronger due to richer linguistic resources.
